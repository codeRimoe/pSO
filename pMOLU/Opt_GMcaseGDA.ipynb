# %%
from model import GDAmodel
import objs
Model = GDAmodel(objs, LUname='LU', thC=.1, z_LU=12, rsam=4, mask=15, path='GMCase')
print(Model.LU.shape)

Model.init_train(500, lr=0.1)
Model.save_inp()
Model.init_train_load('inp', 0.1)
Model.log()
# Out:
# WARNING:tensorflow:From C:\Users\Yue\miniconda3\lib\site-packages\tensorflow\python\compat\v2_compat.py:107: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term
# Loading landuse: LU.tif
# Loading weights: CCM.csv
# Loading weights: CM.csv
# Loading weights: road.tif
# Loading weights: slope.tif
# Loading weights: UUM.csv
# Loading weights: water.tif
# Device mapping:
# /job:localhost/replica:0/task:0/device:GPU:0 -> device: 0, name: NVIDIA GeForce RTX 2080 Ti, pci bus id: 0000:01:00.0, compute capability: 7.5
#
# (850, 804, 12)
# initial...
# Gdp -229924.83 -16274.615
# Eco -129127.52 -59323.406
# Res -121026.41 -7274.7383
# Emp -108923.63 -13613.81
# Aec -50.993374 -23.502136
# E2r 0.14701262 4.108057
# Cpt -67.53253 -52.19655
# [array([2.1365022e+05, 6.9804117e+04, 1.1375167e+05, 9.5309820e+04,
#        2.7491238e+01, 3.9610443e+00, 1.5335983e+01], dtype=float32), array([-2.2992483e+05, -1.2912752e+05, -1.2102641e+05, -1.0892363e+05,
#        -5.0993374e+01,  1.4701262e-01, -6.7532532e+01], dtype=float32), array([302475.12], dtype=float32)]
# ==================
# epoch: None, loss: [2.]
# Gdp: -16249.540646223022, 0.9984592822754411
# Eco: -59345.44729141634, 1.0003715403886866
# Res: -7269.360000000004, 0.999260690757239
# Emp: -13602.82, 0.9991927630355235
# Aec: -23.509297584195167, 1.000304710757192
# E2r: 4.107832, 0.9999452242036768
# Cpt: -52.224353737628974, 1.000532703340245
# Cov: 302566.0, 1.0003004379285734
# {'epoch': None,
#  'loss': array([2.], dtype=float32),
#  'loss1': array([-1.6274615e+04, -5.9323406e+04, -7.2747383e+03, -1.3613810e+04,
#         -2.3502136e+01,  4.1080570e+00, -5.2196548e+01], dtype=float32),
#  'loss2': array([302475.12], dtype=float32),
#  'obs1': array([-1.62495406e+04, -5.93454473e+04, -7.26936000e+03, -1.36028200e+04,
#         -2.35092976e+01,  4.10783200e+00, -5.22243537e+01]),
#  'obs2': array([302566.]),
#  'obs1R': array([0.99845928, 1.00037154, 0.99926069, 0.99919276, 1.00030471,
#         0.99994522, 1.0005327 ]),
#  'obs2R': array([1.00030044]),
#  'Gdp': -16249.540646223022,
#  'Gdpnorm': 0.9984592822754411,
#  'Eco': -59345.44729141634,
#  'Econorm': 1.0003715403886866,
#  'Res': -7269.360000000004,
#  'Resnorm': 0.999260690757239,
#  'Emp': -13602.82,
#  'Empnorm': 0.9991927630355235,
#  'Aec': -23.509297584195167,
#  'Aecnorm': 1.000304710757192,
#  'E2r': 4.107832,
#  'E2rnorm': 0.9999452242036768,
#  'Cpt': -52.224353737628974,
#  'Cptnorm': 1.000532703340245,
#  'Cov': 302566.0,
#  'Covnorm': 1.0003004379285734}

# %%
Model = GDAmodel(objs, LUname='LU', thC=.1, z_LU=12, rsam=4, mask=15, path='GMCase')
Model.init_train_load('inp', 0.1)
Model.perference()
Model.train(n_iter=1000, thStop=1, nprint=None)
# Out:
# Loading landuse: LU.tif
# Loading weights: CCM.csv
# Loading weights: CM.csv
# Loading weights: road.tif
# Loading weights: slope.tif
# Loading weights: UUM.csv
# Loading weights: water.tif
# Device mapping:
# /job:localhost/replica:0/task:0/device:GPU:0 -> device: 0, name: NVIDIA GeForce RTX 2080 Ti, pci bus id: 0000:01:00.0, compute capability: 7.5
#
# [array([2.1365022e+05, 6.9804117e+04, 1.1375167e+05, 9.5309820e+04,
#        2.7491238e+01, 3.9610443e+00, 1.5335983e+01], dtype=float32), array([-2.2992483e+05, -1.2912752e+05, -1.2102641e+05, -1.0892363e+05,
#        -5.0993374e+01,  1.4701262e-01, -6.7532532e+01], dtype=float32), array([302475.12], dtype=float32)]
# ==================
# epoch: 153, loss: [1.8350854]
# Gdp: -39547.03415055995, 2.4299827418979034
# Eco: -63990.7250075266, 1.0786758389742093
# Res: -14611.360000000006, 2.0085066204593924
# Emp: -19779.919999999984, 1.4529305627378437
# Aec: -25.38464848137278, 1.0800996229637838
# E2r: 3.6861279999999996, 0.8972923160936109
# Cpt: -53.47675398218914, 1.0245266317026536
# Cov: 272219.95, 0.8999746673383473

# %%
Model = GDAmodel(objs, LUname='LU', thC=.1, z_LU=12, rsam=4, mask=15, path='GMCase')
Model.init_train_load('inp', 0.1)
Model.perference([1.05, 1, 1, 1, 1, 1, 1])
Model.train(n_iter=1000, thStop=1, nprint=None)
# Out:
# Loading landuse: LU.tif
# Loading weights: CCM.csv
# Loading weights: CM.csv
# Loading weights: road.tif
# Loading weights: slope.tif
# Loading weights: UUM.csv
# Loading weights: water.tif
# Device mapping:
# /job:localhost/replica:0/task:0/device:GPU:0 -> device: 0, name: NVIDIA GeForce RTX 2080 Ti, pci bus id: 0000:01:00.0, compute capability: 7.5
#
# [array([2.1365022e+05, 6.9804117e+04, 1.1375167e+05, 9.5309820e+04,
#        2.7491238e+01, 3.9610443e+00, 1.5335983e+01], dtype=float32), array([-2.2992483e+05, -1.2912752e+05, -1.2102641e+05, -1.0892363e+05,
#        -5.0993374e+01,  1.4701262e-01, -6.7532532e+01], dtype=float32), array([302475.12], dtype=float32)]
# ==================
# epoch: 78, loss: [1.8374312]
# Gdp: -44788.47629582554, 2.75204517285447
# Eco: -64088.38201701166, 1.080322019051488
# Res: -14134.919999999998, 1.943014230000757
# Emp: -20019.75999999999, 1.4705479679734088
# Aec: -25.99222854383334, 1.105951743660492
# E2r: 3.818368, 0.929482716394474
# Cpt: -54.042898797766576, 1.035373035004407
# Cov: 272041.7, 0.8993853626806502

# %%
Model = GDAmodel(objs, LUname='LU', thC=.1, z_LU=12, rsam=4, mask=15, path='GMCase')
Model.init_train_load('inp', 0.1)
Model.perference([1, 1.05, 1, 1, 1, 1, 1])
Model.train(n_iter=1000, thStop=1, nprint=None)
# Out:
# Loading landuse: LU.tif
# Loading weights: CCM.csv
# Loading weights: CM.csv
# Loading weights: road.tif
# Loading weights: slope.tif
# Loading weights: UUM.csv
# Loading weights: water.tif
# Device mapping:
# /job:localhost/replica:0/task:0/device:GPU:0 -> device: 0, name: NVIDIA GeForce RTX 2080 Ti, pci bus id: 0000:01:00.0, compute capability: 7.5
#
# [array([2.1365022e+05, 6.9804117e+04, 1.1375167e+05, 9.5309820e+04,
#        2.7491238e+01, 3.9610443e+00, 1.5335983e+01], dtype=float32), array([-2.2992483e+05, -1.2912752e+05, -1.2102641e+05, -1.0892363e+05,
#        -5.0993374e+01,  1.4701262e-01, -6.7532532e+01], dtype=float32), array([302475.12], dtype=float32)]
# ==================
# epoch: 187, loss: [1.8429239]
# Gdp: -38877.986869840286, 2.3888728741016734
# Eco: -69760.16249028072, 1.1759298209596776
# Res: -13878.24, 1.907730486438247
# Emp: -19010.559999999994, 1.3964173585515796
# Aec: -26.741488033388258, 1.1378322281495388
# E2r: 3.765888, 0.9167078206912882
# Cpt: -53.2712787547155, 1.0205900643715098
# Cov: 272138.4, 0.8997050583911653

# %%
Model = GDAmodel(objs, LUname='LU', thC=.1, z_LU=12, rsam=4, mask=15, path='GMCase')
Model.init_train_load('inp', 0.1)
Model.perference([1, 1, 1.05, 1, 1, 1, 1])
Model.train(n_iter=1000, thStop=1, nprint=None)
# Out:
# Loading landuse: LU.tif
# Loading weights: CCM.csv
# Loading weights: CM.csv
# Loading weights: road.tif
# Loading weights: slope.tif
# Loading weights: UUM.csv
# Loading weights: water.tif
# Device mapping:
# /job:localhost/replica:0/task:0/device:GPU:0 -> device: 0, name: NVIDIA GeForce RTX 2080 Ti, pci bus id: 0000:01:00.0, compute capability: 7.5
#
# [array([2.1365022e+05, 6.9804117e+04, 1.1375167e+05, 9.5309820e+04,
#        2.7491238e+01, 3.9610443e+00, 1.5335983e+01], dtype=float32), array([-2.2992483e+05, -1.2912752e+05, -1.2102641e+05, -1.0892363e+05,
#        -5.0993374e+01,  1.4701262e-01, -6.7532532e+01], dtype=float32), array([302475.12], dtype=float32)]
# ==================
# epoch: 457, loss: [1.8548149]
# Gdp: -32418.33229284665, 1.9919569111761937
# Eco: -62481.065501607765, 1.053227881728517
# Res: -18458.440000000002, 2.5373338924886153
# Emp: -17920.96, 1.3163809811972147
# Aec: -24.77916021999073, 1.054336506988093
# E2r: 3.7845120000000003, 0.9212413507518091
# Cpt: -52.911181355501995, 1.0136911905987305
# Cov: 272235.10000000003, 0.9000247541016804

# %%
Model = GDAmodel(objs, LUname='LU', thC=.1, z_LU=12, rsam=4, mask=15, path='GMCase')
Model.init_train_load('inp', 0.1)
Model.perference([1, 1, 1, 1.05, 1, 1, 1])
Model.train(n_iter=1000, thStop=1, nprint=None)
# Out:
# Loading landuse: LU.tif
# Loading weights: CCM.csv
# Loading weights: CM.csv
# Loading weights: road.tif
# Loading weights: slope.tif
# Loading weights: UUM.csv
# Loading weights: water.tif
# Device mapping:
# /job:localhost/replica:0/task:0/device:GPU:0 -> device: 0, name: NVIDIA GeForce RTX 2080 Ti, pci bus id: 0000:01:00.0, compute capability: 7.5
#
# [array([2.1365022e+05, 6.9804117e+04, 1.1375167e+05, 9.5309820e+04,
#        2.7491238e+01, 3.9610443e+00, 1.5335983e+01], dtype=float32), array([-2.2992483e+05, -1.2912752e+05, -1.2102641e+05, -1.0892363e+05,
#        -5.0993374e+01,  1.4701262e-01, -6.7532532e+01], dtype=float32), array([302475.12], dtype=float32)]
# ==================
# epoch: 407, loss: [1.8880585]
# Gdp: -34611.73543749309, 2.1267314120205247
# Eco: -60582.63885153518, 1.0212265728004313
# Res: -10403.6, 1.4300995579200928
# Emp: -20190.520000000004, 1.4830911138957954
# Aec: -25.063457431079335, 1.0664331610241646
# E2r: 4.068916, 0.9904721327176786
# Cpt: -52.48786246281742, 1.00558109701671
# Cov: 272127.55, 0.8996691876728706

# %%
Model = GDAmodel(objs, LUname='LU', thC=.1, z_LU=12, rsam=4, mask=15, path='GMCase')
Model.init_train_load('inp', 0.1)
Model.perference([1, 1, 1, 1, 1.05, 1, 1])
Model.train(n_iter=1000, thStop=1, nprint=None)
# Out:
# Loading landuse: LU.tif
# Loading weights: CCM.csv
# Loading weights: CM.csv
# Loading weights: road.tif
# Loading weights: slope.tif
# Loading weights: UUM.csv
# Loading weights: water.tif
# Device mapping:
# /job:localhost/replica:0/task:0/device:GPU:0 -> device: 0, name: NVIDIA GeForce RTX 2080 Ti, pci bus id: 0000:01:00.0, compute capability: 7.5
#
# [array([2.1365022e+05, 6.9804117e+04, 1.1375167e+05, 9.5309820e+04,
#        2.7491238e+01, 3.9610443e+00, 1.5335983e+01], dtype=float32), array([-2.2992483e+05, -1.2912752e+05, -1.2102641e+05, -1.0892363e+05,
#        -5.0993374e+01,  1.4701262e-01, -6.7532532e+01], dtype=float32), array([302475.12], dtype=float32)]
# ==================
# epoch: 310, loss: [1.8510776]
# Gdp: -28604.136844085308, 1.7575922030812794
# Eco: -62731.86665593617, 1.0574555748126175
# Res: -12862.200000000004, 1.7680636062401305
# Emp: -18252.199999999997, 1.3407121574406615
# Aec: -27.439401902790948, 1.1675279912307643
# E2r: 3.62104, 0.8814483295934404
# Cpt: -52.959588733842075, 1.014618596332759
# Cov: 272195.45, 0.8998936689421981

# %%
Model = GDAmodel(objs, LUname='LU', thC=.1, z_LU=12, rsam=4, mask=15, path='GMCase')
Model.init_train_load('inp', 0.1)
Model.perference([1, 1, 1, 1, 1, 1.05, 1])
Model.train(n_iter=1000, thStop=1, nprint=None)
# Out:
# Loading landuse: LU.tif
# Loading weights: CCM.csv
# Loading weights: CM.csv
# Loading weights: road.tif
# Loading weights: slope.tif
# Loading weights: UUM.csv
# Loading weights: water.tif
# Device mapping:
# /job:localhost/replica:0/task:0/device:GPU:0 -> device: 0, name: NVIDIA GeForce RTX 2080 Ti, pci bus id: 0000:01:00.0, compute capability: 7.5
#
# [array([2.1365022e+05, 6.9804117e+04, 1.1375167e+05, 9.5309820e+04,
#        2.7491238e+01, 3.9610443e+00, 1.5335983e+01], dtype=float32), array([-2.2992483e+05, -1.2912752e+05, -1.2102641e+05, -1.0892363e+05,
#        -5.0993374e+01,  1.4701262e-01, -6.7532532e+01], dtype=float32), array([302475.12], dtype=float32)]
# ==================
# epoch: 155, loss: [1.8361602]
# Gdp: -37335.432045969734, 2.2940899989518884
# Eco: -63965.00149519557, 1.0782422240832734
# Res: -14484.36, 1.9910489477445763
# Emp: -19683.319999999992, 1.4458348266397978
# Aec: -25.308687891591592, 1.0768675512475663
# E2r: 3.7746079999999997, 0.9188304786663601
# Cpt: -53.21764593010456, 1.019562547683312
# Cov: 272357.05, 0.9004279277510836

# %%
Model = GDAmodel(objs, LUname='LU', thC=.1, z_LU=12, rsam=4, mask=15, path='GMCase')
Model.init_train_load('inp', 0.1)
Model.perference([1, 1, 1, 1, 1, 1, 1.05])
Model.train(n_iter=1000, thStop=1, nprint=None)
# Out:
# Loading landuse: LU.tif
# Loading weights: CCM.csv
# Loading weights: CM.csv
# Loading weights: road.tif
# Loading weights: slope.tif
# Loading weights: UUM.csv
# Loading weights: water.tif
# Device mapping:
# /job:localhost/replica:0/task:0/device:GPU:0 -> device: 0, name: NVIDIA GeForce RTX 2080 Ti, pci bus id: 0000:01:00.0, compute capability: 7.5
#
# [array([2.1365022e+05, 6.9804117e+04, 1.1375167e+05, 9.5309820e+04,
#        2.7491238e+01, 3.9610443e+00, 1.5335983e+01], dtype=float32), array([-2.2992483e+05, -1.2912752e+05, -1.2102641e+05, -1.0892363e+05,
#        -5.0993374e+01,  1.4701262e-01, -6.7532532e+01], dtype=float32), array([302475.12], dtype=float32)]

# %%
Model.log()
# Out:
# ==================
# epoch: 999, loss: [1.8761134]
# Gdp: -29097.335551169628, 1.7878969875558512
# Eco: -62117.18740899257, 1.0470940786376806
# Res: -11846.72, 1.6284737047563458
# Emp: -17428.319999999992, 1.2801941961936765
# Aec: -24.60543822741962, 1.046944753707985
# E2r: 3.911552, 0.9521659458381794
# Cpt: -56.18722680412817, 1.0764548319727685
# Cov: 277106.3, 0.9161292188903136
# {'epoch': 999,
#  'loss': array([1.8761134], dtype=float32),
#  'loss1': array([-2.90987207e+04, -6.21170820e+04, -1.18439795e+04, -1.74288926e+04,
#         -2.46055565e+01,  3.91089177e+00, -5.61871185e+01], dtype=float32),
#  'loss2': array([277108.1], dtype=float32),
#  'obs1': array([-2.90973356e+04, -6.21171874e+04, -1.18467200e+04, -1.74283200e+04,
#         -2.46054382e+01,  3.91155200e+00, -5.61872268e+01]),
#  'obs2': array([277106.3]),
#  'obs1R': array([1.78789699, 1.04709408, 1.6284737 , 1.2801942 , 1.04694475,
#         0.95216595, 1.07645483]),
#  'obs2R': array([0.91612922]),
#  'Gdp': -29097.335551169628,
#  'Gdpnorm': 1.7878969875558512,
#  'Eco': -62117.18740899257,
#  'Econorm': 1.0470940786376806,
#  'Res': -11846.72,
#  'Resnorm': 1.6284737047563458,
#  'Emp': -17428.319999999992,
#  'Empnorm': 1.2801941961936765,
#  'Aec': -24.60543822741962,
#  'Aecnorm': 1.046944753707985,
#  'E2r': 3.911552,
#  'E2rnorm': 0.9521659458381794,
#  'Cpt': -56.18722680412817,
#  'Cptnorm': 1.0764548319727685,
#  'Cov': 277106.3,
#  'Covnorm': 0.9161292188903136}
